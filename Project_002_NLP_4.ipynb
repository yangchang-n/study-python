# %% [markdown]
# <a href="https://colab.research.google.com/github/yangchangnaihoby/AI_7th/blob/master/Project_002_NLP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 50.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 56.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 47.9 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=86761812db0fa5b61da9e0d914e1be62921b608fba3fe5f26c9561790460942b
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import numpy as np
import pandas as pd
from numpy import dot
from numpy.linalg import norm
import urllib.request
from sentence_transformers import SentenceTransformer

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv", filename = "ChatBotData.csv")
train_data = pd.read_csv('ChatBotData.csv')
train_data.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
train_data['embedding'] = train_data.apply(lambda row : model.encode(row.Q), axis = 1)

# %%
def cos_sim(A, B) :
  return dot(A, B) / (norm(A) * norm(B))

# %%
def return_answer(question) :
  embedding = model.encode(question)
  train_data['score'] = train_data.apply(lambda x : cos_sim(x['embedding'], embedding), axis = 1)
  return train_data.loc[train_data['score'].idxmax()]['A']

# %%
def Chatbot_bert() :
  print('마침표 입력시 종료합니다.')
  print()
  while True :
    sentence_input = input()
    if sentence_input == '.' :
      print('종료합니다.')
      break
    print('SBERT :', return_answer(sentence_input))
    print()

# %%
Chatbot_bert()
# Out:
# 마침표 입력시 종료합니다.
#
# 안녕
# SBERT : 안녕하세요.
#
# 오늘 날씨 어때?
# SBERT : 날씨 어플에 물어보세요.
#
# 출근하기 싫어
# SBERT : 직장 스트레스가 심한가봐요.
#
# 커피 마시고 싶다
# SBERT : 카페인이 필요한 시간인가 봐요.
#
# 여행은 어때?
# SBERT : 준비하고 결정하는 게 좋을 거예요.
#
# 너 말 진짜 잘한다
# SBERT : 노력하고 있어요.
#
# 고마워
# SBERT : 감사합니다.
#
# .
# 종료합니다.

# %%
Chatbot_bert()
# Out:
# 마침표 입력시 종료합니다.
#
# 오점머
# SBERT : 소주 한 잔.
#
# .
# 종료합니다.
